# %% [markdown]
# NLTK and SpaCy are two Libraries that are used in NLP Applications

# %% [markdown]
# Difference between SpaCY and NLTK:
#
# SpaCy is Object oriented and NLTK is string processing Library.

# %%
import spacy

# %%
nlp=spacy.load("en_core_web_sm")

doc =nlp("Dr. Strange loves pav bhaji of mumbai.Hulk loves chaat of delhi")

for sentence in doc.sents:
    print(sentence)

# %%
for sentence in doc.sents:
    for word in sentence:
        print(word)

# %%
import nltk
nltk.download("punkt")

# %%
from nltk.tokenize import sent_tokenize

sent_tokenize("Dr. Strange loves pav bhaji of mumbai.Hulk loves chaat of delhi")

# %%
from nltk.tokenize import word_tokenize
word_tokenize("Dr. Strange loves pav bhaji of mumbai.Hulk loves chaat of delhi")

# %% [markdown]
# **Spacy** is better library than nltk...nltk needs customization where as spacy is optimized and chooses the best Algorithim.
#
# **NLTK** is perfect for researchers
#
# **Spacy** is best App  Developers.
#
#
# **Spacy** is **Object oriented**
#
# **NLTK** is **String Processing Library**
